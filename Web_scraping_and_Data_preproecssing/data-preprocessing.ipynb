# %%
# !pip install pycantonese

# %%
import pandas as pd
df = pd.read_csv("posts.csv")
df
# Out:
#        Post_number                                  Title  \
# 0           100000              iOs LIHKG App Load Post問題
# 1           100001                               3月3至7去釜山
# 2           100002                    京城民眾狂放炮仗煙花 空氣污染極速惡化
# 3           100003                                    404
# 4           100004                             （赤口）消費就係投票
# ...            ...                                    ...
# 16809      2001996                    覺唔覺得帶住口罩完全蓋過曬死港女既缺點
# 16810      2001997                    俄再增逾萬病例 醫生投訴裝備不足後墮樓
# 16811      2001998          假如你認同民主黨，請投黃碧雲；假如你認同自己，請忠於自己。
# 16812      2001999                            肌肉按摩槍係咪真係有用
# 16813      2002000  【同Type大對決】VIUTV Kath仔   vs  CCTVB 劉佩玥
#
#                                             Main_content  \
# 0              如題 Load Post Load好耐都Load唔到 試過重Down 係我問題定點
# 1      同女朋友去釜山旅行，細佬未去過泡菜國，女朋友話唔使plan 行程，輕鬆d,但我又唔敢唔pla...
# 2      京津照放炮仗　污染爆錶 \n另一方面，今年春節假期留在國內的民眾，則要繼續忍受霧霾之苦。包括...
# 3                                                    NaN
# 4      件產品/服務做得好，咪有人幫襯\n相反做得無咁好咪消失\n成日聽到咩小商戶做唔住\n事實就係...
# ...                                                  ...
# 16809  港女多數鼻偏 口大 仲要面形多數唔靚 以家帶口罩港女真係屈機 正係用下大眼仔畫下眼影就好正 ...
# 16810  醫生舒勒波夫(左)與同事拍片，稱染疫後仍須如常工作。(互聯網)\n\n俄羅斯的新型冠狀病毒肺...
# 16811                                          每一次投票都問自己
# 16812                            有冇ching有用\n肌肉酸痛個時間縮短到幾多
# 16813                       正皮\n\n\n負皮\n\n\n劉佩玥一講野就覺得佢好煩
#
#                                                 Comments  \
# 0      如題 Load Post Load好耐都Load唔到 試過重Down 係我問題定點, 第10...
# 1      同女朋友去釜山旅行，細佬未去過泡菜國，女朋友話唔使plan 行程，輕鬆d,但我又唔敢唔pla...
# 2      京津照放炮仗　污染爆錶 \n另一方面，今年春節假期留在國內的民眾，則要繼續忍受霧霾之苦。包括...
# 3                                                    NaN
# 4      Agger \n講錢最實際 , 件產品/服務做得好，咪有人幫襯\n相反做得無咁好咪消失\n成...
# ...                                                  ...
# 16809  戴住口罩屌囉, 除口罩就唔會嫁啦, LM等睇伊斯蘭女, 唔覺, 港女多數鼻偏 口大 仲要面形...
# 16810  同中共一L樣, 搵中共埋單啦 做咩對醫護出手, \n醫生舒勒波夫(左)與同事拍片，稱染疫後仍...
# 16811                                          每一次投票都問自己
# 16812  有用,縮短幾多唔敢講\n但有時做完運動有延遲性肌肉酸痛,比枝槍打下真係鬆好多, 有冇chin...
# 16813  Kathy仔正咁多 點比？\nBtw有冇人覺得kathy仔似姜濤\n以上兩位睇到都唔好嬲 純...
#
#                                            URL Category Classification
# 0       https://lihkg.com/thread/100000/page/1       28            站務台
# 1       https://lihkg.com/thread/100001/page/1     None           None
# 2       https://lihkg.com/thread/100002/page/1        5            時事台
# 3       https://lihkg.com/thread/100003/page/1     None           None
# 4       https://lihkg.com/thread/100004/page/1       33            政事台
# ...                                        ...      ...            ...
# 16809  https://lihkg.com/thread/2001996/page/1        6            體育台
# 16810  https://lihkg.com/thread/2001997/page/1        5            時事台
# 16811  https://lihkg.com/thread/2001998/page/1     None           None
# 16812  https://lihkg.com/thread/2001999/page/1        6            體育台
# 16813  https://lihkg.com/thread/2002000/page/1       11            影視台
#
# [16814 rows x 7 columns]

# %%
# Accessing the Yip-Matthews CantoneseEnglish bilingual corpus (Yip and Matthews, 2007)

import pycantonese
url = (
    "https://childes.talkbank.org/"
    "data/Biling/YipMatthews.zip"
)
corpus = pycantonese.read_chat(url)
corpus.n_files()
501
len(corpus.words())
# Out:
# 1949095

# %%
stop_words = pycantonese.stop_words()
#stop_words.add('呢啲') # Manually add stop words
print(stop_words)
# Out:
# {'嘅', '喺', '諗', '同', '咁', '哦', '咪', '邊個', '哩啲', '咩', '你', '而家', '呀', '睇', '但係', '不如', '或者', '有冇', '可能', '到', '乜嘢', '佢', '多', '喎', '由', '好', '又', '噉樣', '再', '太', '原來', '嗰個', '然之後', '想', '啲', '嗰度', '未', '呢', '自己', '都', '返', '已經', '嘢', '哩', '過', '即係', '同埋', '你哋', '幾多', '哩樣', '佢哋', '真係', '會', '吖', '咗', '唔', '如果', '即', '跟住', '人哋', '幾', '最', '唔使', '係', '冇', '成日', '哩個', '乜', '知', '梗係', '一啲', '嗯', '一定', '喺度', '哩度', '所以', '不過', '得', '而', '嗰啲', '有', '啊', '噉', '因為', '應該', '講', '嗰', '唔係', '個', '我哋', '去', '之後', '要', '點', '話', '有啲', '點解', '我', '其他', '點樣', '可以', '就', '覺得', '譬如'}

# %%
len(stop_words)
# Out:
# 104

# %%
import pycantonese
import pandas as pd
import numpy as np 
from pycantonese.word_segmentation import Segmenter
import re

stop_words = pycantonese.stop_words()
segmenter = Segmenter(max_word_length=5)

def preprocess_text(text, keep_eng_num=False):
    # Check if it is a string
    if not isinstance(text, str):
        return ''
    
    # Remove newlines and parentheses first
    text = text.replace('\n', '')  
    text = re.sub(r'[()「」]', '', text)  # Remove parentheses
    
    #Determine whether to retain English and numbers based on the keep_eng_num parameter
    if keep_eng_num:
        # Retain Chinese characters, English characters and numbers, and remove other special symbols
        text = re.sub(r'[^\u4e00-\u9fffA-Za-z0-9]', '', text)
    else:
        # Only keep Chinese characters
        text = re.sub(r'[^\u4e00-\u9fff]', '', text)
    
    # Word segmentation processing
    words = pycantonese.segment(text, cls=segmenter)
    # Remove stop words
    words = [word for word in words if word not in stop_words]
    # Reassemble words into strings
    processed_text = ' '.join(words)
    
    return processed_text

# %%
# Apply text preprocessing, assuming you want to preserve English and numbers
df['Title_preprocessed'] = df['Title'].apply(lambda x: preprocess_text(x, keep_eng_num=True))
df['Comments_preprocessed'] = df['Comments'].apply(lambda x: preprocess_text(x, keep_eng_num=True))
df['Main_content_preprocessed'] = df['Main_content'].apply(lambda x: preprocess_text(x, keep_eng_num=True))

#Apply text preprocessing to retain only Chinese content
df['Title_preprocessed_cn_only'] = df['Title'].apply(lambda x: preprocess_text(x, keep_eng_num=False))
df['Comments_preprocessed_cn_only'] = df['Comments'].apply(lambda x: preprocess_text(x, keep_eng_num=False))
df['Main_content_preprocessed_cn_only'] = df['Main_content'].apply(lambda x: preprocess_text(x, keep_eng_num=False))

# %%
df
# Out:
#        Post_number                                  Title  \
# 0           100000              iOs LIHKG App Load Post問題
# 1           100001                               3月3至7去釜山
# 2           100002                    京城民眾狂放炮仗煙花 空氣污染極速惡化
# 3           100003                                    404
# 4           100004                             （赤口）消費就係投票
# ...            ...                                    ...
# 16809      2001996                    覺唔覺得帶住口罩完全蓋過曬死港女既缺點
# 16810      2001997                    俄再增逾萬病例 醫生投訴裝備不足後墮樓
# 16811      2001998          假如你認同民主黨，請投黃碧雲；假如你認同自己，請忠於自己。
# 16812      2001999                            肌肉按摩槍係咪真係有用
# 16813      2002000  【同Type大對決】VIUTV Kath仔   vs  CCTVB 劉佩玥
#
#                                             Main_content  \
# 0              如題 Load Post Load好耐都Load唔到 試過重Down 係我問題定點
# 1      同女朋友去釜山旅行，細佬未去過泡菜國，女朋友話唔使plan 行程，輕鬆d,但我又唔敢唔pla...
# 2      京津照放炮仗　污染爆錶 \n另一方面，今年春節假期留在國內的民眾，則要繼續忍受霧霾之苦。包括...
# 3                                                    NaN
# 4      件產品/服務做得好，咪有人幫襯\n相反做得無咁好咪消失\n成日聽到咩小商戶做唔住\n事實就係...
# ...                                                  ...
# 16809  港女多數鼻偏 口大 仲要面形多數唔靚 以家帶口罩港女真係屈機 正係用下大眼仔畫下眼影就好正 ...
# 16810  醫生舒勒波夫(左)與同事拍片，稱染疫後仍須如常工作。(互聯網)\n\n俄羅斯的新型冠狀病毒肺...
# 16811                                          每一次投票都問自己
# 16812                            有冇ching有用\n肌肉酸痛個時間縮短到幾多
# 16813                       正皮\n\n\n負皮\n\n\n劉佩玥一講野就覺得佢好煩
#
#                                                 Comments  \
# 0      如題 Load Post Load好耐都Load唔到 試過重Down 係我問題定點, 第10...
# 1      同女朋友去釜山旅行，細佬未去過泡菜國，女朋友話唔使plan 行程，輕鬆d,但我又唔敢唔pla...
# 2      京津照放炮仗　污染爆錶 \n另一方面，今年春節假期留在國內的民眾，則要繼續忍受霧霾之苦。包括...
# 3                                                    NaN
# 4      Agger \n講錢最實際 , 件產品/服務做得好，咪有人幫襯\n相反做得無咁好咪消失\n成...
# ...                                                  ...
# 16809  戴住口罩屌囉, 除口罩就唔會嫁啦, LM等睇伊斯蘭女, 唔覺, 港女多數鼻偏 口大 仲要面形...
# 16810  同中共一L樣, 搵中共埋單啦 做咩對醫護出手, \n醫生舒勒波夫(左)與同事拍片，稱染疫後仍...
# 16811                                          每一次投票都問自己
# 16812  有用,縮短幾多唔敢講\n但有時做完運動有延遲性肌肉酸痛,比枝槍打下真係鬆好多, 有冇chin...
# 16813  Kathy仔正咁多 點比？\nBtw有冇人覺得kathy仔似姜濤\n以上兩位睇到都唔好嬲 純...
#
#                                            URL Category Classification  \
# 0       https://lihkg.com/thread/100000/page/1       28            站務台
# 1       https://lihkg.com/thread/100001/page/1     None           None
# 2       https://lihkg.com/thread/100002/page/1        5            時事台
# 3       https://lihkg.com/thread/100003/page/1     None           None
# 4       https://lihkg.com/thread/100004/page/1       33            政事台
# ...                                        ...      ...            ...
# 16809  https://lihkg.com/thread/2001996/page/1        6            體育台
# 16810  https://lihkg.com/thread/2001997/page/1        5            時事台
# 16811  https://lihkg.com/thread/2001998/page/1     None           None
# 16812  https://lihkg.com/thread/2001999/page/1        6            體育台
# 16813  https://lihkg.com/thread/2002000/page/1       11            影視台
#
#                         Title_preprocessed  \
# 0                   iOsLIHKGAppLoadPost 問題
# 1                             3 月 3 至 7 釜山
# 2              京城 民 眾 狂放 炮仗 煙花 空氣污染 極 速 惡化
# 3                                      404
# 4                              赤口 消費 就係 投票
# ...                                    ...
# 16809             覺 帶住 口罩 完全 蓋 曬 死 港女 既 缺點
# 16810          俄 增 逾 萬 病例 醫生 投訴 裝備 不足 後 墮樓
# 16811       假如 認同 民主黨 請 投 黃 碧 雲 假如 認同 請 忠於
# 16812                        肌肉 按摩 槍 係咪 有用
# 16813  Type 大 對決 VIUTVKath 仔 vsCCTVB 劉 佩 玥
#
#                                    Comments_preprocessed  \
# 0      如題 LoadPostLoad 好耐 Load 試過 重 Down 問題 定點 第 1000...
# 1      女朋友 釜山 旅行 細佬 未去過 泡菜 國 女朋友 plan 行程 輕鬆 d 但 敢 pla...
# 2      京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 3
# 4      Agger 講錢 實際 件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 ...
# ...                                                  ...
# 16809  戴 住口 罩 屌 囉 除 口罩 唔會 嫁 啦 LM 等 伊斯蘭 女 覺 港女 多數 鼻 偏 ...
# 16810  中共 一 L 樣 搵 中共 埋單 啦 做咩 對 醫護 出手 醫生 舒 勒 波 夫 左 與 同...
# 16811                                           每一次 投票 問
# 16812  有用 縮短 敢 但 有時 做完 運動 延遲 性 肌肉 酸痛 比 枝 槍 打下 鬆 好多 ch...
# 16813  Kathy 仔 正 咁多 比 Btw 人 kathy 仔 似 姜 濤 以上 兩 位 睇到 唔...
#
#                                Main_content_preprocessed  \
# 0                如題 LoadPostLoad 好耐 Load 試過 重 Down 問題 定點
# 1      女朋友 釜山 旅行 細佬 未去過 泡菜 國 女朋友 plan 行程 輕鬆 d 但 敢 pla...
# 2      京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 3
# 4      件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住 事實 就係...
# ...                                                  ...
# 16809  港女 多數 鼻 偏 口 大 仲要 面形 多數 靚 以 家 帶 口罩 港女 屈機 正 用下 大...
# 16810  醫生 舒 勒 波 夫 左 與 同事 拍片 稱 染 疫 後 仍 須 如常 工作 互聯網 俄羅斯...
# 16811                                           每一次 投票 問
# 16812                               ching 有用 肌肉 酸痛 時間 縮短
# 16813                                  正皮 負皮 劉 佩 玥 一 野 煩
#
#            Title_preprocessed_cn_only  \
# 0                                  問題
# 1                              月 至 釜山
# 2         京城 民 眾 狂放 炮仗 煙花 空氣污染 極 速 惡化
# 3
# 4                         赤口 消費 就係 投票
# ...                               ...
# 16809        覺 帶住 口罩 完全 蓋 曬 死 港女 既 缺點
# 16810     俄 增 逾 萬 病例 醫生 投訴 裝備 不足 後 墮樓
# 16811  假如 認同 民主黨 請 投 黃 碧 雲 假如 認同 請 忠於
# 16812                   肌肉 按摩 槍 係咪 有用
# 16813                    大 對決 仔 劉 佩 玥
#
#                            Comments_preprocessed_cn_only  \
# 0      如題 好耐 試過 重 問題 定點 第個 岩 岩 先知 既 話就 唔好 拎出 黎 啦 唔知 係...
# 1      女朋友 釜山 旅行 細佬 未去過 泡菜 國 女朋友 行程 輕鬆 但 敢 驚 中伏 加上 諗住...
# 2      京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 3
# 4      講錢 實際 件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住...
# ...                                                  ...
# 16809  戴 住口 罩 屌 囉 除 口罩 唔會 嫁 啦 等 伊斯蘭 女 覺 港女 多數 鼻 偏 口 大...
# 16810  中共 一樣 搵 中共 埋單 啦 做咩 對 醫護 出手 醫生 舒 勒 波 夫 左 與 同事 拍...
# 16811                                           每一次 投票 問
# 16812  有用 縮短 敢 但 有時 做完 運動 延遲 性 肌肉 酸痛 比 枝 槍 打下 鬆 好多 有用...
# 16813  仔 正 咁多 比 人 仔 似 姜 濤 以上 兩 位 睇到 唔好 嬲 純 討論 仔 第一次 出...
#
#                        Main_content_preprocessed_cn_only
# 0                                       如題 好耐 試過 重 問題 定點
# 1      女朋友 釜山 旅行 細佬 未去過 泡菜 國 女朋友 行程 輕鬆 但 敢 驚 中伏 加上 諗住...
# 2      京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 3
# 4      件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住 事實 就係...
# ...                                                  ...
# 16809  港女 多數 鼻 偏 口 大 仲要 面形 多數 靚 以 家 帶 口罩 港女 屈機 正 用下 大...
# 16810  醫生 舒 勒 波 夫 左 與 同事 拍片 稱 染 疫 後 仍 須 如常 工作 互聯網 俄羅斯...
# 16811                                           每一次 投票 問
# 16812                                     有用 肌肉 酸痛 時間 縮短
# 16813                                  正皮 負皮 劉 佩 玥 一 野 煩
#
# [16814 rows x 13 columns]

# %%
def preprocess_data(df):
    df['Title_preprocessed'] = df['Title_preprocessed'].astype(str)
    df['Title_preprocessed_cn_only'] = df['Title_preprocessed_cn_only'].astype(str)# Make sure it is a string type
    return (df
            .sort_values('Post_number')
            .replace({"Title_preprocessed": {"": np.nan, "nan": np.nan, "None": np.nan}})
            .replace({"Title_preprocessed_cn_only": {"": np.nan, "nan": np.nan, "None": np.nan}})
            .query("Classification != 'None' & Title_preprocessed != 'LIHKG'")
            .dropna(subset=['Title', 'Title_preprocessed','Title_preprocessed_cn_only', 'Classification'])
            .drop_duplicates(subset=['Post_number'])
            .reset_index(drop=True))



df = preprocess_data(df)
df
# Out:
#       Post_number                             Title  \
# 0          100000         iOs LIHKG App Load Post問題
# 1          100002               京城民眾狂放炮仗煙花 空氣污染極速惡化
# 2          100004                        （赤口）消費就係投票
# 3          100005          今個新年幾多人比親戚整爛野/被送禮比表弟妹？ 2
# 4          100007                         點解會有咁傻既男仔
# ...           ...                               ...
# 8020      3615839  足總宣布港隊退出電競版亞洲盃　遊戲內港隊名稱欠「China」字眼
# 8021      3615840    區家麟.....「祝願平安，縱使不安，亦能心安，安於不安。」
# 8022      3615841              原來call loan真係發生緊，勁慘情
# 8023      3615844           如果坐高鐵返到香港，約uber司機應該約邊到等
# 8024      3615846                      邊撚個將藥盒設計做六格？
#
#                                            Main_content  \
# 0             如題 Load Post Load好耐都Load唔到 試過重Down 係我問題定點
# 1     京津照放炮仗　污染爆錶 \n另一方面，今年春節假期留在國內的民眾，則要繼續忍受霧霾之苦。包括...
# 2     件產品/服務做得好，咪有人幫襯\n相反做得無咁好咪消失\n成日聽到咩小商戶做唔住\n事實就係...
# 3                               繼續  \n第一次1001左開得慢唔好屌咁大力
# 4     點解你明知我有男朋友都仲中意我\n\n點解我同完你講我地冇可能你仲想留係我身邊\n\n我都中...
# ...                                                 ...
# 8020  中國香港足球總會宣布香港隊退出電競版亞洲盃，因相關遊戲內的港隊名稱欠缺「China」字眼。\...
# 8021  2022 年 4 月 11 日早上 6 時，資深傳媒人區家麟被警察上門拘捕，指控他串謀發布煽...
# 8022                                日日幾十個loan call 問你借錢
# 8023                                                NaN
# 8024             完全唔知市面上設計成六格嘅藥盒有咩用\n星期一至六？星期日休息？\n早午晚？
#
#                                                Comments  \
# 0     如題 Load Post Load好耐都Load唔到 試過重Down 係我問題定點, 第10...
# 1     京津照放炮仗　污染爆錶 \n另一方面，今年春節假期留在國內的民眾，則要繼續忍受霧霾之苦。包括...
# 2     Agger \n講錢最實際 , 件產品/服務做得好，咪有人幫襯\n相反做得無咁好咪消失\n成...
# 3     新年呻苦同砌自己老母\n真係好精彩, 睇完覺得自己原來好幸福.....大陸親戚唔會上嚟(就算...
# 4     厹vs淫閪, 咁你俾次機會我好唔好, 臭雞, 可能佢有苦衷呢\n苦你老母，淫閪就淫閪\n\n...
# ...                                                 ...
# 8020  , 與世界脫軌, 打機都關你足總事, 連登閪聽到電競呢兩個字 好似會上撚晒電, 阿聯酋伊朗直...
# 8021  , 支持歐博， 講真話，行公義，好憐憫, 祝願平安，縱使不安，亦能心安，安於不安。, 202...
# 8022  依家仲有call窿？\n有晒壓測㗎嘛\n2024啦, call窿捐, 套SIR有料，撚班淡淡...
# 8023  , \n要講埋幾多號月台, 要出差啊, 我拎住咁多行李，唔知佢會唔會點我去一個好遠地方, 個...
# 8024  , 認真？, 如果連數都唔識得數。你仲旨意望佢識得用個藥盒去食藥？\n係咪咁戇居呀？俾屋企人...
#
#                                           URL Category Classification  \
# 0      https://lihkg.com/thread/100000/page/1       28            站務台
# 1      https://lihkg.com/thread/100002/page/1        5            時事台
# 2      https://lihkg.com/thread/100004/page/1       33            政事台
# 3      https://lihkg.com/thread/100005/page/1       31            創意台
# 4      https://lihkg.com/thread/100007/page/1       30            感情台
# ...                                       ...      ...            ...
# 8020  https://lihkg.com/thread/3615839/page/1        5            時事台
# 8021  https://lihkg.com/thread/3615840/page/1        5            時事台
# 8022  https://lihkg.com/thread/3615841/page/1       37            房屋台
# 8023  https://lihkg.com/thread/3615844/page/1       20            汽車台
# 8024  https://lihkg.com/thread/3615846/page/1       36            健康台
#
#                               Title_preprocessed  \
# 0                         iOsLIHKGAppLoadPost 問題
# 1                    京城 民 眾 狂放 炮仗 煙花 空氣污染 極 速 惡化
# 2                                    赤口 消費 就係 投票
# 3               今個 新年 人 比 親戚 整 爛 野 被 送禮 比 表弟 妹 2
# 4                                     點解會 傻 既 男仔
# ...                                          ...
# 8020  足總 宣布 港隊 退出 電競 版 亞洲盃 遊戲 內 港隊 名稱 欠 China 字眼
# 8021              區 家 麟 祝願 平安 縱使 不安 亦 能 心安 安於 不安
# 8022                          callloan 發生 緊 勁 慘情
# 8023                  坐 高鐵 返到 香港 約 uber 司機 約 邊 等
# 8024                          邊 撚 將 藥 盒 設計 做 六 格
#
#                                   Comments_preprocessed  \
# 0     如題 LoadPostLoad 好耐 Load 試過 重 Down 問題 定點 第 1000...
# 1     京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 2     Agger 講錢 實際 件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 ...
# 3     新年 呻 苦 砌 老母 精彩 睇完 幸福 大陸 親戚 唔會 上嚟 就算 少 帶埋 細路 香港...
# 4     厹 vs 淫 閪 俾 次 機會 唔好 臭 雞 苦衷 苦 老母 淫 閪 淫 閪 就係 個個 傻...
# ...                                                 ...
# 8020  與 世界 脫軌 打機 關 足總 事 連 登 閪 聽到 電競 兩個字 好似 上 撚 晒 電 阿...
# 8021  支持 歐 博 講真 行 公義 憐憫 祝願 平安 縱使 不安 亦 能 心安 安於 不安 202...
# 8022  依家 仲有 call 窿 晒 壓 測 嘛 2024 啦 call 窿 捐 套 SIR 有料 ...
# 8023  講埋 號 月 台 出差 拎住 咁多 行李 唔知 唔會 一個 遠 地方 pickuppoint...
# 8024  認真 連 數 識得 數 仲 旨意 望 識得 用 藥 盒 去食 藥 係咪 戇居 俾 屋企人 幫...
#
#                               Main_content_preprocessed  \
# 0               如題 LoadPostLoad 好耐 Load 試過 重 Down 問題 定點
# 1     京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 2     件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住 事實 就係...
# 3                           繼續 第一次 1001 左 開 慢 唔好 屌 咁大 力
# 4        明知 男朋友 仲 中意 完 地 仲想 留 身邊 中意 但 地 亦 傷害 唔好 對 好好 唔好
# ...                                                 ...
# 8020  中國香港 足球 總會 宣布 香港 隊 退出 電競 版 亞洲盃 因 相關 遊戲 內 的 港隊 ...
# 8021  2022 年 4 月 11 日 早上 6 時 資深 傳媒 人 區 家 麟 被 警察 上門 拘...
# 8022                                日日 幾十 loancall 問 借錢
# 8023
# 8024   完全 唔知 市面 上 設計 成 六 格 藥 盒 有咩用 星期一 至 六 星期日 休息 早 午 晚
#
#                 Title_preprocessed_cn_only  \
# 0                                       問題
# 1              京城 民 眾 狂放 炮仗 煙花 空氣污染 極 速 惡化
# 2                              赤口 消費 就係 投票
# 3           今個 新年 人 比 親戚 整 爛 野 被 送禮 比 表弟 妹
# 4                               點解會 傻 既 男仔
# ...                                    ...
# 8020  足總 宣布 港隊 退出 電競 版 亞洲盃 遊戲 內 港隊 名稱 欠 字眼
# 8021        區 家 麟 祝願 平安 縱使 不安 亦 能 心安 安於 不安
# 8022                             發生 緊 勁 慘情
# 8023                 坐 高鐵 返到 香港 約 司機 約 邊 等
# 8024                    邊 撚 將 藥 盒 設計 做 六 格
#
#                           Comments_preprocessed_cn_only  \
# 0     如題 好耐 試過 重 問題 定點 第個 岩 岩 先知 既 話就 唔好 拎出 黎 啦 唔知 係...
# 1     京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 2     講錢 實際 件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住...
# 3     新年 呻 苦 砌 老母 精彩 睇完 幸福 大陸 親戚 唔會 上嚟 就算 少 帶埋 細路 香港...
# 4     厹 淫 閪 俾 次 機會 唔好 臭 雞 苦衷 苦 老母 淫 閪 淫 閪 就係 個個 傻仔 就...
# ...                                                 ...
# 8020  與 世界 脫軌 打機 關 足總 事 連 登 閪 聽到 電競 兩個字 好似 上 撚 晒 電 阿...
# 8021  支持 歐 博 講真 行 公義 憐憫 祝願 平安 縱使 不安 亦 能 心安 安於 不安 年月日...
# 8022  依家 仲有 窿 晒 壓 測 嘛 啦 窿 捐 套 有料 撚 班 淡淡 日日 幾十 問 借錢 識...
# 8023  講埋 號 月 台 出差 拎住 咁多 行李 唔知 唔會 一個 遠 地方 邊 停車場 自動 個位...
# 8024  認真 連 數 識得 數 仲 旨意 望 識得 用 藥 盒 去食 藥 係咪 戇居 俾 屋企人 幫...
#
#                       Main_content_preprocessed_cn_only
# 0                                      如題 好耐 試過 重 問題 定點
# 1     京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 2     件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住 事實 就係...
# 3                                繼續 第一次 左 開 慢 唔好 屌 咁大 力
# 4        明知 男朋友 仲 中意 完 地 仲想 留 身邊 中意 但 地 亦 傷害 唔好 對 好好 唔好
# ...                                                 ...
# 8020  中國香港 足球 總會 宣布 香港 隊 退出 電競 版 亞洲盃 因 相關 遊戲 內 的 港隊 ...
# 8021  年月日 早上 時 資深 傳媒 人 區 家 麟 被 警察 上門 拘捕 指控 他 串謀 發布 煽...
# 8022                                         日日 幾十 問 借錢
# 8023
# 8024   完全 唔知 市面 上 設計 成 六 格 藥 盒 有咩用 星期一 至 六 星期日 休息 早 午 晚
#
# [8025 rows x 13 columns]

# %%
category_counts = df['Classification'].value_counts()
print(category_counts)
# Out:
# 時事台      1859
# 感情台       853
# 體育台       758
# 娛樂台       566
# 創意台       470
# 財經台       333
# 飲食台       301
# 上班台       268
# 學術台       258
# 影視台       221
# 遊戲台       221
# 動漫台       184
# 房屋台       166
# 硬件台       148
# 校園台       146
# 旅遊台       144
# 音樂台       143
# 手機台       140
# 潮流台       119
# 汽車台       118
# 健康台       107
# 政事台        73
# Apps台      68
# 寵物台        63
# 軟件台        53
# 攝影台        49
# 直播台        28
# World      26
# 講故台        24
# 站務台        23
# 電訊台        20
# 活動台        20
# 玩具台        20
# 家庭台        20
# 美容台         6
# 電器台         5
# 黑洞          4
# Name: Classification, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_long_tail_distribution(data, category_column):
    # Set graphic style
    sns.set(style='whitegrid', font_scale=1.2)

    # Count the number of each category
    category_counts = data[category_column].value_counts()

    # Sort by quantity
    sorted_categories = category_counts.sort_values(ascending=False).index

    # Set the graphic size
    plt.figure(figsize=(12, 6))

    # Draw a count plot of a long tail distribution
    sns.countplot(data=data, x=category_column, order=sorted_categories, palette='viridis')

    # Set the labels and titles
    plt.xlabel(category_column)
    plt.ylabel('Count')
    plt.title('Distribution of {} (Long-Tailed)'.format(category_column))

    # Adjust the display of x-axis labels to avoid overlap
    plt.xticks(rotation=90)

    # Display graphics
    plt.show()
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
plot_long_tail_distribution(df, 'Category')

# %%
def get_word_count(text):
    return len(str(text).split())


df['word_count(comments)'] = df['Comments_preprocessed'].apply(get_word_count)

count = 0  
for index, row in df.iterrows():
    if row['word_count(comments)'] < 50:
        count += 1  
print("The total number of rows with less than 50 tokens：", count)
# Out:
# 少於50個token的行數總數： 1047

# %%
df[['Post_number','Title_preprocessed','Main_content_preprocessed','Comments_preprocessed',
    'Title_preprocessed_cn_only','Main_content_preprocessed_cn_only','Comments_preprocessed_cn_only',
    'word_count(comments)','URL','Category','Classification']]
# Out:
#       Post_number                          Title_preprocessed  \
# 0          100000                      iOsLIHKGAppLoadPost 問題
# 1          100002                 京城 民 眾 狂放 炮仗 煙花 空氣污染 極 速 惡化
# 2          100004                                 赤口 消費 就係 投票
# 3          100005            今個 新年 人 比 親戚 整 爛 野 被 送禮 比 表弟 妹 2
# 4          100007                                  點解會 傻 既 男仔
# ...           ...                                         ...
# 8020      3615839  足總 宣布 港隊 退出 電競 版 亞洲盃 遊戲 內 港隊 名稱 欠 China 字眼
# 8021      3615840              區 家 麟 祝願 平安 縱使 不安 亦 能 心安 安於 不安
# 8022      3615841                          callloan 發生 緊 勁 慘情
# 8023      3615844                  坐 高鐵 返到 香港 約 uber 司機 約 邊 等
# 8024      3615846                          邊 撚 將 藥 盒 設計 做 六 格
#
#                               Main_content_preprocessed  \
# 0               如題 LoadPostLoad 好耐 Load 試過 重 Down 問題 定點
# 1     京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 2     件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住 事實 就係...
# 3                           繼續 第一次 1001 左 開 慢 唔好 屌 咁大 力
# 4        明知 男朋友 仲 中意 完 地 仲想 留 身邊 中意 但 地 亦 傷害 唔好 對 好好 唔好
# ...                                                 ...
# 8020  中國香港 足球 總會 宣布 香港 隊 退出 電競 版 亞洲盃 因 相關 遊戲 內 的 港隊 ...
# 8021  2022 年 4 月 11 日 早上 6 時 資深 傳媒 人 區 家 麟 被 警察 上門 拘...
# 8022                                日日 幾十 loancall 問 借錢
# 8023
# 8024   完全 唔知 市面 上 設計 成 六 格 藥 盒 有咩用 星期一 至 六 星期日 休息 早 午 晚
#
#                                   Comments_preprocessed  \
# 0     如題 LoadPostLoad 好耐 Load 試過 重 Down 問題 定點 第 1000...
# 1     京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 2     Agger 講錢 實際 件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 ...
# 3     新年 呻 苦 砌 老母 精彩 睇完 幸福 大陸 親戚 唔會 上嚟 就算 少 帶埋 細路 香港...
# 4     厹 vs 淫 閪 俾 次 機會 唔好 臭 雞 苦衷 苦 老母 淫 閪 淫 閪 就係 個個 傻...
# ...                                                 ...
# 8020  與 世界 脫軌 打機 關 足總 事 連 登 閪 聽到 電競 兩個字 好似 上 撚 晒 電 阿...
# 8021  支持 歐 博 講真 行 公義 憐憫 祝願 平安 縱使 不安 亦 能 心安 安於 不安 202...
# 8022  依家 仲有 call 窿 晒 壓 測 嘛 2024 啦 call 窿 捐 套 SIR 有料 ...
# 8023  講埋 號 月 台 出差 拎住 咁多 行李 唔知 唔會 一個 遠 地方 pickuppoint...
# 8024  認真 連 數 識得 數 仲 旨意 望 識得 用 藥 盒 去食 藥 係咪 戇居 俾 屋企人 幫...
#
#                 Title_preprocessed_cn_only  \
# 0                                       問題
# 1              京城 民 眾 狂放 炮仗 煙花 空氣污染 極 速 惡化
# 2                              赤口 消費 就係 投票
# 3           今個 新年 人 比 親戚 整 爛 野 被 送禮 比 表弟 妹
# 4                               點解會 傻 既 男仔
# ...                                    ...
# 8020  足總 宣布 港隊 退出 電競 版 亞洲盃 遊戲 內 港隊 名稱 欠 字眼
# 8021        區 家 麟 祝願 平安 縱使 不安 亦 能 心安 安於 不安
# 8022                             發生 緊 勁 慘情
# 8023                 坐 高鐵 返到 香港 約 司機 約 邊 等
# 8024                    邊 撚 將 藥 盒 設計 做 六 格
#
#                       Main_content_preprocessed_cn_only  \
# 0                                      如題 好耐 試過 重 問題 定點
# 1     京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...
# 2     件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住 事實 就係...
# 3                                繼續 第一次 左 開 慢 唔好 屌 咁大 力
# 4        明知 男朋友 仲 中意 完 地 仲想 留 身邊 中意 但 地 亦 傷害 唔好 對 好好 唔好
# ...                                                 ...
# 8020  中國香港 足球 總會 宣布 香港 隊 退出 電競 版 亞洲盃 因 相關 遊戲 內 的 港隊 ...
# 8021  年月日 早上 時 資深 傳媒 人 區 家 麟 被 警察 上門 拘捕 指控 他 串謀 發布 煽...
# 8022                                         日日 幾十 問 借錢
# 8023
# 8024   完全 唔知 市面 上 設計 成 六 格 藥 盒 有咩用 星期一 至 六 星期日 休息 早 午 晚
#
#                           Comments_preprocessed_cn_only  word_count(comments)  \
# 0     如題 好耐 試過 重 問題 定點 第個 岩 岩 先知 既 話就 唔好 拎出 黎 啦 唔知 係...                    35
# 1     京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼...                   341
# 2     講錢 實際 件 產品 服務 做 咪有 人 幫襯 相反 做 無咁 消失 聽到 小 商戶 做 住...                    66
# 3     新年 呻 苦 砌 老母 精彩 睇完 幸福 大陸 親戚 唔會 上嚟 就算 少 帶埋 細路 香港...                   269
# 4     厹 淫 閪 俾 次 機會 唔好 臭 雞 苦衷 苦 老母 淫 閪 淫 閪 就係 個個 傻仔 就...                   122
# ...                                                 ...                   ...
# 8020  與 世界 脫軌 打機 關 足總 事 連 登 閪 聽到 電競 兩個字 好似 上 撚 晒 電 阿...                   471
# 8021  支持 歐 博 講真 行 公義 憐憫 祝願 平安 縱使 不安 亦 能 心安 安於 不安 年月日...                   337
# 8022  依家 仲有 窿 晒 壓 測 嘛 啦 窿 捐 套 有料 撚 班 淡淡 日日 幾十 問 借錢 識...                   109
# 8023  講埋 號 月 台 出差 拎住 咁多 行李 唔知 唔會 一個 遠 地方 邊 停車場 自動 個位...                    79
# 8024  認真 連 數 識得 數 仲 旨意 望 識得 用 藥 盒 去食 藥 係咪 戇居 俾 屋企人 幫...                   225
#
#                                           URL Category Classification
# 0      https://lihkg.com/thread/100000/page/1       28            站務台
# 1      https://lihkg.com/thread/100002/page/1        5            時事台
# 2      https://lihkg.com/thread/100004/page/1       33            政事台
# 3      https://lihkg.com/thread/100005/page/1       31            創意台
# 4      https://lihkg.com/thread/100007/page/1       30            感情台
# ...                                       ...      ...            ...
# 8020  https://lihkg.com/thread/3615839/page/1        5            時事台
# 8021  https://lihkg.com/thread/3615840/page/1        5            時事台
# 8022  https://lihkg.com/thread/3615841/page/1       37            房屋台
# 8023  https://lihkg.com/thread/3615844/page/1       20            汽車台
# 8024  https://lihkg.com/thread/3615846/page/1       36            健康台
#
# [8025 rows x 11 columns]

# %%
# Save the dataframe as csv file

df[['Post_number','Title_preprocessed','Main_content_preprocessed','Comments_preprocessed',
    'Title_preprocessed_cn_only','Main_content_preprocessed_cn_only','Comments_preprocessed_cn_only',
    'word_count(comments)','URL','Category','Classification']].to_csv("preprocessed_data.csv",encoding='utf-8-sig',index=False)

# %%
import csv

data_list = []

with open('preprocessed_data.csv', 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    next(reader)  # Skip the first row (column headers)
    for row in reader:
        data_dict = {'text': row[3], 'label1': row[-2], 'label2':row[-1]}
        data_list.append(data_dict)


for data in data_list[:30]:
    print(data)
# Out:
# {'text': '如題 LoadPostLoad 好耐 Load 試過 重 Down 問題 定點 第 100000 post 岩 岩 先知 103beta1 既 話就 唔好 拎出 黎 啦 唔知 係唔係 AppStore 103103beta1 既 話就 唔好 拎出 黎 啦 第 100000 post', 'label1': '28', 'label2': '站務台'}
# {'text': '京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼續 忍受 霧霾 之 苦 包括 北京 等 國內 城市 近日 均 對 市民 燃放 煙花 爆竹 祭 出 嚴 控 姿態 惟 民 眾 仍 堅持 爆竹 一聲 除 舊 歲 其中 京津 冀 大批 民 眾 前晚 開始 燃放 炮仗 令 區域 PM25 懸浮粒子 濃度 急 升官 方 公佈 北京 的 空氣 質量 指數 AQI 在 昨 凌晨 1 時 至 5 時 超過 500 達 嚴重 污染 的 爆錶 水平 若 用 美國 標準 更 曾 升 至 724 的 峯值 至 昨早 天明 時 才 有所改善 京津 照 放炮 仗 污染 爆錶 另一方面 今年 春節 假期 留 在 國內 的 民 眾 則 繼續 忍受 霧霾 之 苦 包括 北京 等 國內 城市 近日 均 對 市民 燃放 煙花 爆竹 祭 出 嚴 控 姿態 惟 民 眾 仍 堅持 爆竹 一聲 除 舊 歲 其中 京津 冀 大批 民 眾 前晚 開始 燃放 炮仗 令 區域 PM25 懸浮粒子 濃度 急 升官 方 公佈 北京 的 空氣 質量 指數 AQI 在 昨 凌晨 1 時 至 5 時 超過 500 達 嚴重 污染 的 爆錶 水平 若 用 美國 標準 更 曾 升 至 724 的 峯值 至 昨早 天明 時 才 有所改善 支那 另外 有一套 標準 香港 行緊 另一 套 標準 支那 點會 放假 毒 霧 吸 慣 京津 照 放
 125 角 大一 陣 有無 聽日 啦 攰 喇 一陣 有無 聽日 啦 攰 喇 用 d 足球 app 買 左 皇馬 初 盤 105 角 大 買 曬 單 雙 用嚟 刷 投注 數據 刷 丫 心諗 買 輸 買 晒 單 雙 鬥氣 者 買 both 咩玩法 解釋 左 買 輸 買 晒 兩邊 一邊 贏 喇 掛 既 意思 鬥氣 75 撚 慘 慘 番 5 蚊 一陣 有無', 'label1': '6', 'label2': '體育台'}
# {'text': '用緊 rmx650 用緊 rmx650 淘 寶 d 上網 見 人地 RMx 系統 線 有電 容 入面 YouTube 搵 CorsairType4CableMod 模組 線 跟 埋 電容 淘 寶 果 見 問下 影響 大 大駛 駛 俾 幾百 買 CableMod 答 用 silverstone 細 牛 跟 大陸 某 毒 壇 d 壕 推介 商家 訂 左 set 用 左 年 無咩 問題 一 set 2 百幾 3 百 上網 見 人地 RMx 系統 線 有電 容 入面 YouTube 搵 CorsairType4CableMod 模組 線 跟 埋 電容 淘 寶 果 見 問下 影響 大 大駛 駛 俾 幾百 買 CableMod 答 用 silverstone 細 牛 跟 大陸 某 毒 壇 d 壕 推介 商家 訂 左 set 用 左 年 無咩 問題 一 set 2 百幾 3 百 YY 上網 見 人地 RMx 系統 線 有電 容 入面 YouTube 搵 CorsairType4CableMod 模組 線 跟 埋 電容 淘 寶 果 見 問下 影響 大 大駛 駛 俾 幾百 買 CableMod 問 中 田 有得 訂 4 至 6 禮拜 corsairofficialcableCES2017show 出 黎 隻 款 中 田 有得 訂 4 至 6 禮拜 corsairofficialcableCES2017show 出 黎 隻 款 官 網 上網 見 人地 RMx 系統 線 有電 容 入面 YouTube 搵 CorsairType4CableMod 模組 線 跟 埋 電容 淘 寶 果 見 問下 影響 大 大駛 駛 俾 幾百 買 CableMod 答 用 silverstone 細 牛 跟 大陸 某 毒 壇 d 壕 推介 商家 訂 左 set 用 左 年 無咩 問題 一 set 2 百幾 3 百 YYYY 包 線 好玩 中 田 有得 訂 4 至 6 禮拜 corsairofficialcableCES2017show 出 黎 隻 款 官 網 官 網 corsair 隻 上網 見 人地 RMx 系統 線 有電 容 入面 YouTube 搵 CorsairType4CableMod 模組 線 跟 埋 電容 淘 寶 果 見 問下 影響 大 大駛 駛 俾 幾百 買 CableMod 中 田 有得 訂 4 至 6 禮拜', 'label1': '22', 'label2': '硬件台'}
# {'text': '3000fasttrade2000dc 仔 識 用 用返 iphone 啦 fasttrade20002100 即日 交收 買 左 部 RX100M5 L 識 用 點算 識 乜春 先 識 開機 faattradehk800 可 即日 交收 時間 地點 650 收 左 毅進 星 100fasttrade20002100 即日 交收 2150 交收 100 萬 500 收 左 出 夠 2k 即時 交收', 'label1': '23', 'label2': '攝影台'}
去到 新城區 望 返去 舊城區 嘩 靚 傻 左 認真 用 類似 背景 影 左 超過 兩 百 張 自拍 風格 圖 風景 圖 啦 其實 影 好樣 衰 準備 左 其他人 影 既 相 俾 大家 睇波 爾 圖 的 街道 左 世上 美的 書店 右 HarryPotter 中 移動 的 樓梯 的 靈感 在此 產生 波 爾 圖 的 街道 左 波 爾 圖 的 河岸 右 波 爾 圖 的 夜景 波 爾 圖 的 街道 左 葡萄牙 電車 內 觀 右 懷念 既 酒廠 試 portwine 葡萄牙 瓷磚 葡萄牙 瓷磚 藝術 葡萄牙 每一 處 見到 既 蹤影 街頭 屋企 裝飾 碗碟 等等 難 見到 瓷磚 摩爾人 埃及人 引入 歐洲 既 但 葡萄牙 直至 15 世紀 先 開始 興起 當時 葡國 國王 欣賞 西班牙 格拉 那 達 阿 爾 罕 布 拉 宮 Sintra 興趣 宮殿 時 要求 加入 大量 瓷磚 初時 只係 淨色 簡單 圖案 既 瓷磚 後來 16 世紀 受 西洋 畫 影響 令 葡萄牙 既 瓷磚 變 得色 彩 繽紛 後來 受 明朝 青花瓷 影響 大量 瓷磚 以 藍 白 為 主 色 Porto 街頭 瓷磚 鳩 拍 留名 屌 走 畀 歐 遊 半年 問 答 post 啦 波圖 除咗 舊 炸 包 之外 牛雜 出名 嗰陣 差 衝動 買 罐 罐頭 牛雜 香港 最後 放棄 介紹 先 加 亞 新城 簡稱 新城 葡萄牙 產 酒 區 城 入面 好多 酒廠 酒窖 好多 人 參觀 試 酒 識 飲 鍾意 飲 既 關係 就冇 安排 呢個 行程 啦 繼續 影 夠 風格 圖 開始 闖 上去 之前 講白 色 圓 圓 地 既 建築 啦 本身 打算 上個 個位 日落 就冇 跟 地圖 純粹 亂咁 行走 入 橫街窄巷 冒 下 險 沿途 影 既 真 葡國 雞 左 隻 雞 葡萄牙 代表 物 之一 傳說 顯靈 拯救 左一 無辜 既 朝聖者 公正 信任 和好 運 既 象徵 葡萄牙 既 吉 詳 物 張相 入面 隻 全世界 最大 既 葡萄牙 公雞 公仔 新城 比 舊 城 冷清 好多 左 沿路 D 廢棄 建築 D 流浪貓 右 順住 D 山 既 小巷 廢棄 建築 行 左 十分 鐘 左右 果 陣 沿路 一個人 開心 行 行 撞到 一 男 一 女 啪啪啪 緊 地 著衫 望住 地 地 望住 即刻 華麗 轉身 跑走 扮 無 野 下 真心 淆底 驚 黎 滅 口 諗諗下 危險 好彩 今次 阻 人 扑 野 啫 下次 撞到 人 劈友 罪行 客死 異鄉 唔知 發生 咩事 亂 行 搵到 靚 既 位 新城區 既 小巷 食完 飯 甜品 天 黑 晒 自由 廣場 again 唔知 building 見 靚 影 左 唔記得 左 做咩 影 人間 店 好似 俾 間店 d 公仔 嚇親 一 開始 個個 火車站 既 外觀 夜晚 靚 想睇 鐵 橋 夜景 落 河邊 條鐵 橋 夜晚 靚 好多 打算 挑戰 中午 挑戰 失敗 個個 圓形 打卡 位 左 橋 今次 googlemap 行 真心 行到 粗口 講埋 睇相 地圖 好似 近 但 兜路 條 路 仲 鬼死咁 斜 45 度 fuckfuck 本身 區 中午 冷清 入黑 成個 area 一個人 一個人 行 勁 驚 行 左 好耐 終於 睇到 夜景 見到 目的地 孝感 動 天 老味 仲要 兜 大路 先 去到 最高 個位 圓形 建築物 既 門口 呢個 位 見到 既 夜景 靚 終於 上 行 左 超過 半個鐘 大 斜路 高炒 條 橋 靚 hostel 沖涼 訓 覺 之前 舊 登 Post 但 打 完 搬 黎 繼續 打 另外 第 2 post 講緊 保加利亞 開始 post 啦 一路 upload 先覺 各位 巴絲 打 遊記 詳細 勁 淨係 upload 圖 煩 喊 仲有 十幾 國家 打 是 的 今年 上年 啦 四月 果 陣 見 Barcelona 好似 靚 機票 平 於是 狗衝 左 機票 全個 旅程 交通 包括 兩 程 火車 一 程 夜車 四 程 飛機 2000hkd 有找 實數 唔記得 啦 耐 之前 雖然 最後 Barcelona 比較上 咁鍾意 既 地方 今次 旅程  ...
# {'text': '食糊 糊 辛辣麵 想要 一 底 想要 1 一齊 分 曬 d 蘿蔔糕 鐘意 食 杯 麵 蘿蔔糕 利申 仲有 8 底 俾 一 底 黎 ok 今年 新年 無 食過 上 黎 煎 比 您 食屎 雜扒 餐 打邊爐 油渣 麵 好似 正 蘿蔔糕 利申 仲有 8 底 食 屋企 無 想要 1 一齊 分 曬 d 蘿蔔糕 蘿蔔糕 加 年糕 加 芋頭糕 糕 全部 糕 肚餓 食乜 屎 比 d 質素 回覆 蘿蔔糕 利申 仲有 8 底 俾 一 底 黎 ok 今年 新年 無 食過 三 養 蘿蔔糕 利申 仲有 8 底 俾 一 底 黎 ok 今年 新年 無 食過 想要 一 底 想要 俾 一 底 黎 ok 今年 新年 無 食過 想要 一 底 想要 1 蘿蔔糕 利申 仲有 8 底 烚 餃 蘿蔔糕 利申 仲有 8 底 俾 一 底 黎 ok 今年 新年 無 食過 想要 一 底 啱啱 食 左 杏仁餅 正 蘿蔔糕 利申 仲有 8 底 俾 一 底 黎 ok 今年 新年 無 食過 上 黎 煎 比 您 食 嚟 屋企 邊', 'label1': '16', 'label2': '飲食台'}
# {'text': '新手 求 評 張 正 新手 求 評 太大 mb 手機 up 新手 求 評 巴打 日系 風格 可 教下 小弟 點整 張 正 左 韓國 雪 楚 格 峰 符 茲 堡 之前 旅行 相 終於 有時 間 執 不定 時 更新 今日 2 張 正 希望 各位 比 評語 小弟 更進一步', 'label1': '23', 'label2': '攝影台'}
# {'text': '夾 線 有時 開心 又話 呃 鳩 手掌 一路好走 屌 老母 夾 線 有時 開心 又話 呃 鳩 屌 老母 臭花閪 夾 線 有時 開心 偷影 男朋友 仲 大波 搞到 自卑 屌 露 linbtwbam 肥仔波 大過 女朋友 悲劇 胸肌 定 肥仔波 胸肌 既 摩 牙 無 波 既 女人 被 列入 傷殘 人士 之內 做咩 影 對 波 出 黎 扮 女 巴打 夾 線 有時 開心 女仔 影 夾 出 男仔 幫 影 扮 女 唉 痴 撚 線 真 定假 男朋友 重', 'label1': '30', 'label2': '感情台'}
